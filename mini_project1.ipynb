# %% [markdown]
# #Import and Upload Data

# %%
#import library
import numpy as np
import itertools
from sklearn.neural_network import MLPClassifier, MLPRegressor
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import load_diabetes, load_digits
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB
import pandas as pd
from sklearn.datasets import make_classification, make_regression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from mlxtend.plotting import plot_decision_regions
import __main__
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from pandas_datareader.data import DataReader

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDClassifier
from scipy import stats
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPClassifier
import seaborn as sns

# %% [markdown]
# Load dataset

# %%
https://drive.google.com/file/d/1CH9RzRlTZHLXdwkRDvcsvLrPxdVDLIPt/view?usp=sharing
# Out:
#   File "<ipython-input-1-957c6adf67cf>", line 1
#     https://drive.google.com/file/d/1CH9RzRlTZHLXdwkRDvcsvLrPxdVDLIPt/view?usp=sharing
#                                     ^
# SyntaxError: invalid decimal literal

# %%
https://drive.google.com/file/d/18nBBXwTydzUCFMjyrGYwJkGhH9GLbWYj/view?usp=sharing
# Out:
#   File "<ipython-input-2-ec01bd3d7afd>", line 1
#     https://drive.google.com/file/d/18nBBXwTydzUCFMjyrGYwJkGhH9GLbWYj/view?usp=sharing
#                                      ^
# SyntaxError: invalid decimal literal

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 1CH9RzRlTZHLXdwkRDvcsvLrPxdVDLIPt
# !gdown 18nBBXwTydzUCFMjyrGYwJkGhH9GLbWYj
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1CH9RzRlTZHLXdwkRDvcsvLrPxdVDLIPt
# From (redirected): https://drive.google.com/uc?id=1CH9RzRlTZHLXdwkRDvcsvLrPxdVDLIPt&confirm=t&uuid=c37c5218-ea8f-4acf-a1bf-eaae777b714d
# To: /content/97.mat
# 100% 3.90M/3.90M [00:00<00:00, 98.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=18nBBXwTydzUCFMjyrGYwJkGhH9GLbWYj
# From (redirected): https://drive.google.com/uc?id=18nBBXwTydzUCFMjyrGYwJkGhH9GLbWYj&confirm=t&uuid=a69808e1-4b78-425c-82e8-14fbe7c6444d
# To: /content/105.mat
# 100% 2.91M/2.91M [00:00<00:00, 82.5MB/s]

# %%
https://drive.google.com/file/d/1HzvmyIo0CPhG10TNpLkbCG5WZR9U6m37/view?usp=sharing

# %%
# !gdown 1HzvmyIo0CPhG10TNpLkbCG5WZR9U6m37
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1HzvmyIo0CPhG10TNpLkbCG5WZR9U6m37
# To: /content/weatherHistory.csv
# 100% 16.3M/16.3M [00:00<00:00, 61.5MB/s]

# %% [markdown]
# #q1

# %% [markdown]
# ##q1-2

# %%
#to build the dataset
x,y = make_classification(n_samples=1000 , n_features=3,n_informative=2
                          , n_redundant=0
                          , n_repeated=0                                                     # تعداد ویژگی های تکراری
                          , n_classes=4
                          , n_clusters_per_class=1
                          , random_state=64)

#to show the dataset dimentions
print ("Dataset dimension :")
print ("number of samples:", x.shape[0])
print ("number of features:", x.shape[1])
print ("number of classes:",len(set(y)))
plt.scatter(x[:,0],x[:,1], c=y)
# Out:
# Dataset dimension :
# number of samples: 1000
# number of features: 3
# number of classes: 4

# %% [markdown]
# ##q1-3 ,4

# %% [markdown]
# LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=64, shuffle=True)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 3), (200, 3), (800,), (200,))

# %%
model1 = LogisticRegression(solver='saga', C=1.0, max_iter=10000, tol=1e-4, random_state= 64)
model1.fit(x_train , y_train)
model1.predict(x_test) , y_test
model1.predict_proba(x_test) , y_test
# Out:
# (array([[3.61738262e-01, 3.34317526e-04, 6.37927414e-01, 6.76347034e-09],
#         [1.30294336e-04, 9.96960335e-01, 7.54639843e-13, 2.90937076e-03],
#         [9.76106927e-01, 9.94122476e-03, 1.39518315e-02, 1.63357627e-08],
#         [1.68525594e-03, 9.94192971e-01, 5.64455471e-10, 4.12177266e-03],
#         [9.93745791e-01, 3.42693713e-03, 2.82727196e-03, 2.99539300e-11],
#         [5.80657741e-04, 9.96231336e-01, 2.79002167e-11, 3.18800630e-03],
#         [4.96224408e-04, 7.21795756e-07, 9.99493864e-01, 9.19006592e-06],
#         [8.49117978e-01, 1.19184990e-01, 3.08470095e-02, 8.50022313e-04],
#         [1.39483693e-01, 7.70891291e-01, 1.54942934e-04, 8.94700722e-02],
#         [1.55782847e-02, 6.05906786e-02, 4.52936573e-04, 9.23378100e-01],
#         [1.31548094e-03, 3.46872178e-02, 4.16624613e-06, 9.63993135e-01],
#         [1.32651007e-03, 6.43374886e-05, 6.84245204e-01, 3.14363948e-01],
#         [1.82482341e-02, 6.04205478e-02, 7.77602553e-04, 9.20553616e-01],
# ...

# %%
acc_ta=model1.score(x_train, y_train)
acc_te=model1.score(x_test, y_test)
acc_ta , acc_te
# Out:
# (0.96125, 0.93)

# %% [markdown]
# SGDClassifier

# %%
model2 =SGDClassifier(loss='log_loss', random_state=64,  max_iter= 2000)
model2.fit(x_train, y_train)
model2.predict(x_test),y_test

acc_ta= model2.score(x_train, y_train)
acc_te= model2.score(x_test, y_test)
acc_ta, acc_te
# Out:
# (0.96125, 0.935)

# %%
x1_min , x2_min , x3_min  = x.mean(0)
x1_min
# Out:
# -0.017589329879635844

# %%
# Create a meshgrid using all three features
h = .02  # step size in the mesh
# Calculate the minimum and maximum values for the first feature (column) in X -1 and +1 are to make it safe
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
# Calculate the minimum and maximum values for the second feature (column) in X
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
# Calculate the minimum and maximum values for the third feature (column) in X
z_min, z_max = x[:, 2].min() - 1, x[:, 2].max() + 1

# Create a meshgrid using the ranges defined by x_min, x_max, y_min, y_max, z_min, z_max, and step size h
xx, yy, zz = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h), np.arange(z_min, z_max, h))

# Predict labels for all data points in the meshgrid
meshgrid_data = np.c_[xx.ravel(), yy.ravel(), zz.ravel()]
Z = model1.predict(meshgrid_data)
Z = Z.reshape(xx.shape)

# Plot decision boundaries
plt.figure(figsize=(10, 6))
plt.contourf(xx[:, :, 0], yy[:, :, 0], Z[:, :, 0], alpha=0.4)

# Plot data points
scatter = plt.scatter(x[:, 0], x[:, 1], c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Decision Boundaries and Data Points')

# Add a colorbar for reference
plt.colorbar(scatter, label='Class')
plt.show()

# %%
# to show all 3 features
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # Importing Axes3D from mpl_toolkits.mplot3d
import numpy as np

# xx, yy, zz, and Z are defined from  previous code

# Create a 3D figure
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot decision boundaries in 3D
ax.plot_surface(xx[:, :, 0], yy[:, :, 0], zz[:, :, 0], alpha=0.4)

# Plot data points in 3D
scatter = ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, edgecolors='k', cmap=plt.cm.Paired)

# Set labels and title
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.set_zlabel('Feature 3')
ax.set_title('Decision Boundaries and Data Points in 3D')

# Add a colorbar for reference
plt.colorbar(scatter, label='Class')

# Show plot
plt.show()

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=64)

# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Define parameter grid for grid search
param_grid = {
    'alpha': [0.0001, 0.001, 0.01, 0.1, 1.0],
    'max_iter': [1000, 1500, 2000, 2500],
    'learning_rate': ['constant', 'optimal', 'adaptive'],
    'eta0': [0.01, 0.1, 0.5, 1.0]
}

# Perform grid search
sgd = SGDClassifier(loss='log', random_state=64)
grid_search = GridSearchCV(sgd, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train_scaled, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Train the model with best parameters
best_model = SGDClassifier(loss='log_loss', **best_params, random_state=64)
best_model.fit(x_train_scaled, y_train)

# Evaluate the model
test_score = best_model.score(x_test_scaled, y_test)

# Print results
print("Best Parameters:", best_params)
print("Training Accuracy (CV):", best_score)
print("Test Accuracy:", test_score)
# Out:
# Best Parameters: {'alpha': 0.0001, 'eta0': 1.0, 'learning_rate': 'adaptive', 'max_iter': 1000}
# Training Accuracy (CV): 0.96
# Test Accuracy: 0.93
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %%
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=64)

# Feature scaling
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Define parameter grid for grid search
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10],
    'max_iter': [1000, 1500, 2000, 2500],
    'tol': [1e-4, 1e-3, 1e-2]
}

# Perform grid search
model1 = LogisticRegression(solver='saga', random_state=64)
grid_search = GridSearchCV(model1, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(x_train_scaled, y_train)

# Get best parameters and score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# Train the model with best parameters
best_model = LogisticRegression(solver='saga', **best_params, random_state=64)
best_model.fit(x_train_scaled, y_train)

# Evaluate the model
test_score = best_model.score(x_test_scaled, y_test)

# Print results
print("Best Parameters:", best_params)
print("Training Accuracy (CV):", best_score)
print("Test Accuracy:", test_score)
# Out:
# Best Parameters: {'C': 10, 'max_iter': 1000, 'tol': 0.0001}
# Training Accuracy (CV): 0.9637500000000001
# Test Accuracy: 0.945

# %% [markdown]
# ##q1-5

# %%
#Install drawdata
# !pip install drawdata
# !pip install pandas polars
from drawdata import ScatterWidget

# %%
#Draw data
widget = ScatterWidget()
widget
# Out:
# ScatterWidget()

# %%
import numpy as np

# Extract data from widget and convert to pandas DataFrame
data = widget.data_as_pandas

# Combine 'x' and 'y' columns into a single array
x = data[['x', 'y']].values

# Convert 'label' column to binary values: 1 if 'a', otherwise 0
y = (data['label'] == 'a').astype(int).values
# Plot the data points in different colors based on the label
plt.scatter(x[y == 1, 0], x[y == 1, 1], c='blue', label='Class A')
plt.scatter(x[y == 0, 0], x[y == 0, 1], c='red', label='Class B')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter plot of x and y with different colors for labels')
plt.legend()
plt.show()
x.shape , y.shape
# Out:
# ((395, 2), (395,))

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size= 0.2, random_state= 64)
#model1
model1= LogisticRegression(solver='saga', C=1.0, max_iter=10000, tol=1e-4, random_state= 64)
model1.fit(x_train ,y_train)
model1.predict(x_test ), y_test
model1.score(x_test, y_test)

#model2
model2= SGDClassifier(loss='log_loss', random_state=74,  max_iter= 2000)
model2.fit(x_train ,y_train)
model2.predict(x_test ), y_test
model2.score(x_test, y_test)


model2.score(x_test, y_test), model1.score(x_test, y_test), model2.score(x_train, y_train), model1.score(x_train, y_train)
# Out:
# (0.8987341772151899,
#  0.8860759493670886,
#  0.8955696202531646,
#  0.8987341772151899)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=64)

# Define ranges for max_iter and learning rates
max_iters_model1 = [100, 500, 1000, 5000, 10000]
max_iters_model2 = [100, 500, 1000, 2000, 3000]
learning_rates_model1 = [0.001, 0.01, 0.1, 1.0]
learning_rates_model2 = [0.001, 0.01, 0.1, 1.0]

best_score = -1
best_max_iter_model1 = None
best_max_iter_model2 = None
best_lr_model1 = None
best_lr_model2 = None

# Iterate over max_iter and learning rate combinations
for max_iter_model1 in max_iters_model1:
    for max_iter_model2 in max_iters_model2:
        for lr_model1 in learning_rates_model1:
            for lr_model2 in learning_rates_model2:
                # Train model1
                model1 = LogisticRegression(solver='saga', C=1.0, max_iter=max_iter_model1, tol=1e-4, random_state=64)
                model1.fit(x_train, y_train)

                # Train model2
                model2 = SGDClassifier(loss='log_loss', learning_rate='constant', eta0=lr_model2, random_state=64, max_iter=max_iter_model2)
                model2.fit(x_train, y_train)

                # Evaluate models on the test set
                score_model1 = model1.score(x_test, y_test)
                score_model2 = model2.score(x_test, y_test)

                # Check if the combined score is better than the current best score
                combined_score = (score_model1 + score_model2) / 2
                if combined_score > best_score:
                    best_score = combined_score
                    best_max_iter_model1 = max_iter_model1
                    best_max_iter_model2 = max_iter_model2
                    best_lr_model1 = lr_model1
                    best_lr_model2 = lr_model2

# Print the best combination of max_iter and learning rates
print("Best combination of max_iter and learning rates:")
print("Model 1 max_iter:", best_max_iter_model1)
print("Model 2 max_iter:", best_max_iter_model2)
print("Model 1 learning rate:", best_lr_model1)
print("Model 2 learning rate:", best_lr_model2)
print("Combined Score:", best_score)
# Out:
# Best combination of max_iter and learning rates:
# Model 1 max_iter: 100
# Model 2 max_iter: 100
# Model 1 learning rate: 0.001
# Model 2 learning rate: 0.1
# Combined Score: 0.9285714285714286

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# Assuming x and y are your data
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=64)

# Fit Logistic Regression model
model1 = LogisticRegression(solver='saga', C=1.0, max_iter=10000, tol=1e-4, random_state=64)
model1.fit(x_train, y_train)

# Fit SGD Classifier model
model2 = SGDClassifier(loss='log', random_state=74, max_iter=2000)
model2.fit(x_train, y_train)

# Plot decision boundaries
x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))
f, axarr = plt.subplots(1, 2, sharex='col', sharey='row', figsize=(10, 5))

for idx, clf, title in zip([0, 1],
                           [model1, model2],
                           ['Logistic Regression', 'SGD Classifier']):
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    axarr[idx].contourf(xx, yy, Z, alpha=0.4)
    axarr[idx].scatter(x[:, 0], x[:, 1], c=y,
                       s=20, edgecolor='k')
    axarr[idx].set_title(title)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# #q2

# %% [markdown]
# ##q2-2-1

# %%
import numpy as np

import scipy.io

output_normal = '97.mat'  # Output file name for normal dataset
output_fault = '105.mat'   # Output file name for fault dataset


# Load the datasets using scipy
data_normal = scipy.io.loadmat(output_normal)
data_fault = scipy.io.loadmat(output_fault)

# Print the keys present in the loaded dictionaries
print("Keys in data_normal:", data_normal.keys())
print("Keys in data_fault:", data_fault.keys())
# Out:
# Keys in data_normal: dict_keys(['__header__', '__version__', '__globals__', 'X097_DE_time', 'X097_FE_time', 'X097RPM'])
# Keys in data_fault: dict_keys(['__header__', '__version__', '__globals__', 'X105_DE_time', 'X105_FE_time', 'X105_BA_time', 'X105RPM'])

# %%
#columne of normal and fualts
columns_data_normal = list(data_normal.keys())[-3:]
columns_data_fault = list(data_fault.keys())[-4:]
columns_data_fault
# Out:
# ['X105_DE_time', 'X105_FE_time', 'X105_BA_time', 'X105RPM']

# %%
all_columns= np.concatenate((columns_data_normal, columns_data_fault ))
all_columns
# Out:
# array(['X097_DE_time', 'X097_FE_time', 'X097RPM', 'X105_DE_time',
#        'X105_FE_time', 'X105_BA_time', 'X105RPM'], dtype='<U12')

# %%
mat = {}
M, N = 200, 200

for label, datasets in {'normal': data_normal, 'fault': data_fault}.items():
    if label == 'normal':
        cols = columns_data_normal
    elif label == 'fault':
        cols = columns_data_fault
    else:
        continue  # Skip if label is not recognized

    for col in cols:
        mat1 = np.zeros((M, N))
        for j in range(M):
            if j + N <= len(datasets[col]):
                mat1[j, :] = datasets[col][j:j+N].reshape(-1,)
            else:
                break  # Exit the loop if the window exceeds bounds of data
        mat[f"{label}_{col}"] =mat1

# %%
desired_col1 = 'X097_DE_time'
desired_col2 = 'X105_DE_time'


x_normal= mat['normal_' + desired_col1]
x_fault= mat['fault_' + desired_col2]

# %% [markdown]
# ##q2-2-2

# %%
import numpy as np
from scipy.stats import skew

# Define feature extraction functions
def calculate_standard_deviation(data):
    return np.std(data, axis=0)

def find_peak(data):
    return np.max(data, axis=0)

def calculate_crest_factor(data):
    peak_value = find_peak(data)
    rms_value = np.sqrt(np.mean(data ** 2, axis=0))
    return peak_value / rms_value

def calculate_skewness(data):
    return skew(data, axis=0)

def calculate_clearance_factor(data):
    peak_to_peak = np.ptp(data, axis=0)
    rms_value = np.sqrt(np.mean(data ** 2, axis=0))
    return peak_to_peak / rms_value

def calculate_peak_to_peak(data):
    return np.ptp(data, axis=0)

def calculate_shape_factor(data):
    mean_value = np.mean(data, axis=0)
    std_value = np.std(data, axis=0)
    return std_value / mean_value

def calculate_impact_factor(data):
    peak_value = find_peak(data)
    mean_value = np.mean(data, axis=0)
    return peak_value / mean_value

# %%
class Features:
    def __init__(self, matrix):
        self.matrix = matrix
        self._extract()

    def _extract(self):
        self.features = {
            'standard deviation': stats.tstd(self.matrix, axis=1),
            'peak': np.max(self.matrix, axis=1),
            'skewness': stats.skew(self.matrix, axis=1),
            'square root mean': np.square(np.mean(np.sqrt(np.abs(self.matrix)), axis=1)),
            'kurtosis': stats.kurtosis(self.matrix, axis=1),
            'crest factor': np.max(self.matrix, axis=1) / np.sqrt(np.mean(np.square(self.matrix), axis=1)),
            'clearance factor': np.max(self.matrix, axis=1) / np.square(np.mean(np.sqrt(np.abs(self.matrix)), axis=1)),
            'mean': np.mean(self.matrix, axis=1),
            'absolute mean': np.mean(np.abs(self.matrix), axis=1),
            'root mean square': np.sqrt(np.mean(np.square(self.matrix), axis=1)),
        }

    def __getitem__(self, key):
        return self.features[key]

# Create instances of the Features class for the specified matrices
normal_features = Features(x_normal)
fault_features = Features(x_fault)


# Print features for one of the matrices to verify the output
print("Features for 'X097_FE_time':", normal_features.features)
# Out:
# Features for 'X097_FE_time': {'standard deviation': array([0.08911261, 0.08925179, 0.08915669, 0.08894252, 0.08900243,
#        0.08947406, 0.08995879, 0.09007799, 0.08997108, 0.08989488,
#        0.08994169, 0.09022804, 0.09082224, 0.09137663, 0.09151516,
#        0.09140746, 0.09138366, 0.09166666, 0.09209845, 0.09242939,
#        0.09255778, 0.09258142, 0.0925069 , 0.09242277, 0.09251227,
#        0.09267688, 0.09273778, 0.09271337, 0.09272709, 0.09274913,
#        0.09268146, 0.09249929, 0.09236003, 0.09237416, 0.092421  ,
#        0.09244664, 0.09245965, 0.0924385 , 0.09246869, 0.09266726,
#        0.09294069, 0.09308398, 0.09303589, 0.09295097, 0.09291322,
#        0.09291604, 0.09298474, 0.09310661, 0.09297829, 0.09247865,
#        0.09193409, 0.09153887, 0.09121653, 0.09095345, 0.09086253,
#        0.09100204, 0.09124818, 0.09150506, 0.0918527 , 0.09225864,
#        0.09250834, 0.09253772, 0.09246096, 0.0923601 , 0.09231504,
# ...

# %%
import pandas as pd
import numpy as np

df_normal = pd.DataFrame(normal_features.features)
df_fault = pd.DataFrame(fault_features.features)


df_normal['label'] = 0
df_fault['label'] = 1



# Concatenate all datasets into a single DataFrame
final_dataset = pd.concat([df_normal, df_fault, ], ignore_index=True)

final_dataset
# Out:
#      standard deviation      peak  skewness  square root mean  kurtosis  \
# 0              0.089113  0.217794 -0.397733          0.067061 -0.486965
# 1              0.089252  0.217794 -0.399411          0.067258 -0.495745
# 2              0.089157  0.217794 -0.398388          0.067129 -0.489671
# 3              0.088943  0.217794 -0.391586          0.066625 -0.477665
# 4              0.089002  0.217794 -0.374608          0.066596 -0.493006
# ..                  ...       ...       ...               ...       ...
# 395            0.246839  1.160112  0.518065          0.143180  3.188446
# 396            0.247560  1.160112  0.513050          0.143756  3.122116
# 397            0.247811  1.160112  0.508872          0.143860  3.108061
# 398            0.248228  1.160112  0.525337          0.144092  3.093327
# 399            0.254866  1.160112  0.642138          0.145561  3.120598
#
#      crest factor  clearance factor      mean  absolute mean  \
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Split data into features (X) and labels (y)
X = final_dataset .drop('label', axis=1).values
y = final_dataset ['label'].values

# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=64, shuffle=True)

# Further split test set into validation and final test sets
X_val, X_final_test, y_val, y_final_test = train_test_split(X_test, y_test, test_size=0.5, random_state=64, shuffle=True)

# Standardize data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_final_test_scaled = scaler.transform(X_final_test)

# %% [markdown]
# ##q2-3

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

class LogisticRegression:
    def __init__(self, n_iter=20, learning_rate=0.05, random_state=None):
        self.n_iter = n_iter
        self.eta = learning_rate
        np.random.seed(random_state)

    def _weight_init(self, num_features):
        self.w = np.random.rand(num_features) * 0
        self.b = np.random.rand()

    def _update(self, x, E):
        dj = np.dot(x.T, E)
        self.w += self.eta * dj
        self.b += self.eta * np.sum(E)

    def forward(self, x):
        z = np.dot(x, self.w) + self.b
        a = 1 / (1 + np.exp(-z))
        y_hat = np.array([1 if hat > 0.5 else 0 for hat in a])
        return y_hat

    def error(self, predict, true):
        E = true - predict
        e = 1 / len(true) * np.dot(E, E)
        return E, e

    def train(self, x, y):
        num_features = x.shape[1]
        self._weight_init(num_features)
        self.loss = []
        for iter in range(self.n_iter):
            y_hat = self.forward(x)
            E, e = self.error(y_hat, y)
            self.loss.append(e)
            self._update(x, E)

    def predict(self, x):
        return self.forward(x)

# Assuming x_train_scaled, y_train, x_test_scaled, and y_test are already defined

# Train the model
model = LogisticRegression(n_iter=20, learning_rate=0.001, random_state=64)
model.train(X_train_scaled, y_train)

# Plot loss
plt.plot(model.loss)
plt.title('Error per epoch')
plt.grid(True)
plt.ylabel('Error')
plt.xlabel('Iteration')
plt.show()

# Predict on test data
y_pred = model.predict(X_final_test_scaled)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Assuming you have X_train_scaled, y_train, X_test, y_test

# Initialize the SGDClassifier with correct parameters
model2 = SGDClassifier(loss='log', random_state=64, max_iter=2000)

# Fit the model
model2.fit(X_train_scaled, y_train)

# Predict on test data
predictions = model2.predict(X_test)

# Calculate accuracy
acc_ta = model2.score(X_train_scaled, y_train)
acc_te = model2.score(X_test, y_test)

acc_ta, acc_te
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(
# (1.0, 0.5)

# %%
import numpy as np
from sklearn.metrics import log_loss

# Initialize the SGDClassifier with correct parameters
model2 = SGDClassifier(loss='log', random_state=64, max_iter=2000)

# Lists to store training losses per epoch
train_losses = []

# Number of epochs
epochs = 2000  # Assuming you want to train for 2000 epochs

# Training loop
for epoch in range(epochs):
    # Perform one epoch of training
    model2.partial_fit(X_train_scaled, y_train, classes=np.unique(y_train))

    # Calculate training loss for this epoch
    y_pred_proba = model2.predict_proba(X_train_scaled)
    train_loss = log_loss(y_train, y_pred_proba)

    # Append the loss to the list
    train_losses.append(train_loss)

# Plot the error per epoch
plt.plot(range(1, epochs + 1), train_losses)
plt.title('Error per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_stochastic_gradient.py:163: FutureWarning: The loss 'log' was deprecated in v1.1 and will be removed in version 1.3. Use `loss='log_loss'` which is equivalent.
#   warnings.warn(

# %% [markdown]
# # q3

# %% [markdown]
# ##q3-1

# %%
data = pd.read_csv ('/content/weatherHistory.csv')
data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
a=data.groupby('Humidity').size()
b=data.groupby('Temperature (C)').size()
c=data.groupby('Apparent Temperature (C)').size()
print (a,b,c)
df= data[['Apparent Temperature (C)','Humidity','Temperature (C)']]
df
# Out:
# Humidity
# 0.00      22
# 0.12       1
# 0.13       1
# 0.14       4
# 0.15      10
#         ...
# 0.96    3843
# 0.97     582
# 0.98     253
# 0.99    1576
# 1.00    2890
# Length: 90, dtype: int64 Temperature (C)
# -21.822222    1
# -21.111111    3
# -20.783333    1
# -20.555556    2
# -20.277778    1
#              ..
#  38.861111    1
#  38.866667    1
#  38.983333    3
#  39.588889    1
#  39.905556    1
# Length: 7574, dtype: int64 Apparent Temperature (C)
# -27.716667    1
# -26.227778    1
# -25.922222    1
# -25.200000    1
# -25.072222    1
#              ..
#  38.255556    1
#  38.377778    1
#  38.416667    1
#  38.661111    1
#  39.344444    1
# Length: 8984, dtype: int64
#        Apparent Temperature (C)  Humidity  Temperature (C)
# 0                      7.388889      0.89         9.472222
# 1                      7.227778      0.86         9.355556
# 2                      9.377778      0.89         9.377778
# ...

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Apparent Temperature (C)'}>,
#         <Axes: title={'center': 'Humidity'}>],
#        [<Axes: title={'center': 'Temperature (C)'}>, <Axes: >]],
#       dtype=object)

# %%
import seaborn as sns

correlation_matrix = df.corr()

plt.figure(figsize=(10, 8))
heatmap = sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('heatmap')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
# Plotting scatter histogram
sns.pairplot(df)
plt.suptitle('Scatter Histogram of features', y=1.02)
plt.show()

# %% [markdown]
# ## q3-2

# %%
import numpy as np
import matplotlib.pyplot as plt

class LinearRegressionLS:
    def __init__(self):
        self.coefficients = None

    def fit(self, X, y):
        # Add a column of ones to account for the intercept term
        X = np.column_stack((np.ones(len(X)), X))

        # Compute the coefficients using the least squares method
        self.coefficients = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

    def predict(self, X):
        # Add a column of ones to account for the intercept term
        X = np.column_stack((np.ones(len(X)), X))

        # Predict the target variable
        return X.dot(self.coefficients)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

np.random.seed(64)

# Splitting data into train and test sets
df_train, df_test = train_test_split(df, test_size=0.1)

scaler = StandardScaler()

variables = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity']
models = {}
metrics = {}

# Create a new figure to contain all plots
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):

    # Input of model
    input_train = df_train[variables[i-1]].values.reshape(-1, 1)
    output_train = df_train[var].values.reshape(-1, 1)
    input_test = df_test[variables[i-1]].values.reshape(-1, 1)
    output_test = df_test[var].values.reshape(-1, 1)

    # Normalizing values
    input_train_scaled = scaler.fit_transform(input_train)
    input_test_scaled = scaler.transform(input_test)
    output_train_scaled = scaler.fit_transform(output_train)
    output_test_scaled = scaler.transform(output_test)

    # Model fitting
    lr = LinearRegressionLS()
    lr.fit(input_train_scaled, output_train_scaled)
    models[var] = lr  # Save all linear regression models

    # Plot Train
    plt.subplot(2, 3, i+1)
    plt.scatter(input_train_scaled, output_train_scaled, c='green', label='Real Data')
    hat_train = lr.predict(input_train_scaled)
    plt.plot(input_train_scaled, hat_train, c='orange', linewidth=2, label='Prediction')
    plt.title('Train: ' + var)
    plt.ylabel(var)
    plt.xlabel(variables[i-1])
    plt.legend()

    # Plot Test
    plt.subplot(2, 3, i+4)
    plt.scatter(input_test_scaled, output_test_scaled, c='blue', label='Real Data')
    hat_test = lr.predict(input_test_scaled)
    plt.plot(input_test_scaled, hat_test, c='orange', linewidth=2, label='Prediction')
    plt.title('Test: ' + var)
    plt.ylabel(var)
    plt.xlabel(variables[i-1])
    plt.legend()

# Adjust layout
plt.tight_layout()

# Displaying plots
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import pandas as pd

# Dictionary to store models and metrics
ls_models = {}
metrics = {}

for i, v in enumerate(variables):

    # Input of model
    input_train = df_train[variables[i-1]].values.reshape(-1, 1)
    output_train = df_train[v].values.reshape(-1, 1)
    input_test = df_test[variables[i-1]].values.reshape(-1, 1)
    output_test = df_test[v].values.reshape(-1, 1)

    # Normalizing values
    input_train_scaled = scaler.fit_transform(input_train)
    input_test_scaled = scaler.transform(input_test)
    output_train_scaled = scaler.fit_transform(output_train)
    output_test_scaled = scaler.transform(output_test)

    # Model fitting
    lr = LinearRegressionLS()
    lr.fit(input_train_scaled, output_train_scaled)

    # Save model
    ls_models[v] = lr

    # Predictions
    hat_train = lr.predict(input_train_scaled)
    hat_test = lr.predict(input_test_scaled)

    # Calculating metrics
    mse_train = mean_squared_error(output_train_scaled, hat_train)
    mse_test = mean_squared_error(output_test_scaled, hat_test)
    mae_train = mean_absolute_error(output_train_scaled, hat_train)
    mae_test = mean_absolute_error(output_test_scaled, hat_test)

    # Saving metrics
    metrics[f'{variables[i-1]} and {v}'] = {'MSE Train': mse_train, 'MSE Test': mse_test, 'MAE Train': mae_train, 'MAE Test': mae_test}

# Converting metrics dictionary to DataFrame
metrics_df = pd.DataFrame(metrics)
print("Model Evaluation Metrics:")
print(metrics_df.to_string())
# Out:
# Model Evaluation Metrics:
#            Humidity and Temperature (C)  Temperature (C) and Apparent Temperature (C)  Apparent Temperature (C) and Humidity
# MSE Train                      0.601280                                      0.014685                               0.638064
# MSE Test                       0.594208                                      0.014723                               0.624849
# MAE Train                      0.632627                                      0.092823                               0.647424
# MAE Test                       0.626825                                      0.092677                               0.642558

# %% [markdown]
# rls

# %%
import numpy as np
import matplotlib.pyplot as plt

class RecursiveLeastSquares:
    def __init__(self, n_features, forgetting_factor=0.99):
        self.n_features = n_features
        self.forgetting_factor = forgetting_factor
        self.theta = np.zeros((n_features, 1))  # Initialize model parameters
        self.P = np.eye(n_features)  # Initialize covariance matrix

    def fit(self, X, y):
        errors = []
        for i in range(len(X)):
            x_i = X[i].reshape(-1, 1)
            y_i = y[i]

            # Predict
            y_pred = np.dot(x_i.T, self.theta)

            # Update
            error = y_i - y_pred
            errors.append(error)
            K = np.dot(self.P, x_i) / (self.forgetting_factor + np.dot(np.dot(x_i.T, self.P), x_i))
            self.theta = self.theta + np.dot(K, error)
            self.P = (1 / self.forgetting_factor) * (self.P - np.dot(K, np.dot(x_i.T, self.P)))

        return errors

    def predict(self, X):
        return np.dot(X, self.theta)

# %%
vars = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity']
rls_models = {}
metrics = {}

fig, axes = plt.subplots(len(vars), 2, figsize=(12, 8))

for i, v in enumerate(vars):

    # Input of model
    input_train = df_train[vars[i-1]].values.reshape(-1, 1)
    output_train = df_train[v].values.reshape(-1, 1)
    input_test = df_test[vars[i-1]].values.reshape(-1, 1)
    output_test = df_test[v].values.reshape(-1, 1)

    # Normalizing values
    input_train_scaled = scaler.fit_transform(input_train)
    input_test_scaled = scaler.transform(input_test)
    output_train_scaled = scaler.fit_transform(output_train)
    output_test_scaled = scaler.transform(output_test)

    # Continous variable
    in_range = np.max(input_train_scaled) - np.min(input_train_scaled)
    t = np.arange(
        np.min(input_train_scaled)-0.1*in_range,
        np.max(input_train_scaled)+0.1*in_range,
        0.1
    )

    # Model fitting
    rls = RecursiveLeastSquares(n_features=1, forgetting_factor=0.999)
    rls.fit(input_train_scaled, output_train_scaled)
    rls_models[v] = rls  # Save all LS models
    hat_train = rls.predict(t.reshape(-1, 1))
    hat_test = rls.predict(input_test_scaled)

    # Plot Train
    axes[i, 0].scatter(input_train_scaled, output_train_scaled, c='green', label='Real Data')
    axes[i, 0].plot(t, hat_train, c='orange', linewidth=2, label='Prediction')
    axes[i, 0].set_title('Train')
    axes[i, 0].set_ylabel(v)
    axes[i, 0].set_xlabel(vars[i-1])
    axes[i, 0].legend()

    # Plot Test
    axes[i, 1].scatter(input_test_scaled, output_test_scaled, c='blue', label='Real Data')
    axes[i, 1].plot(input_test_scaled, hat_test, c='orange', linewidth=2, label='Prediction')
    axes[i, 1].set_title('Test')
    axes[i, 1].set_ylabel(v)
    axes[i, 1].set_xlabel(vars[i-1])
    axes[i, 1].legend()

    # Calculating metrics
    mse_train = mean_squared_error(rls.predict(input_train_scaled), output_train_scaled)
    mse_test = mean_squared_error(hat_test, output_test_scaled)
    mae_train = mean_absolute_error(rls.predict(input_train_scaled), output_train_scaled)
    mae_test = mean_absolute_error(hat_test, output_test_scaled)
    metrics[v] = {'MSE Train': mse_train, 'MSE Test': mse_test, 'MAE Train': mae_train, 'MAE Test': mae_test}

plt.tight_layout()
plt.show()

# %%
vars = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity']
rls_models = {}
metrics = {}

for i, v in enumerate(vars):

    # Input of model
    input_train = df_train[vars[i-1]].values.reshape(-1, 1)
    output_train = df_train[v].values.reshape(-1, 1)
    input_test = df_test[vars[i-1]].values.reshape(-1, 1)
    output_test = df_test[v].values.reshape(-1, 1)

    # Normalizing values
    input_train_scaled = scaler.fit_transform(input_train)
    input_test_scaled = scaler.transform(input_test)
    output_train_scaled = scaler.fit_transform(output_train)
    output_test_scaled = scaler.transform(output_test)

    # Model fitting
    rls = RecursiveLeastSquares(n_features=1, forgetting_factor=0.999)
    rls.fit(input_train_scaled, output_train_scaled)
    rls_models[v] = rls

    # Predictions
    hat_train = rls.predict(input_train_scaled)
    hat_test = rls.predict(input_test_scaled)

    # Calculating metrics
    mse_train = mean_squared_error(output_train_scaled, hat_train)
    mse_test = mean_squared_error(output_test_scaled, hat_test)
    mae_train = mean_absolute_error(output_train_scaled, hat_train)
    mae_test = mean_absolute_error(output_test_scaled, hat_test)
    metrics[f'{vars[i-1]} and {v}'] = {'MSE Train': mse_train, 'MSE Test': mse_test, 'MAE Train': mae_train, 'MAE Test': mae_test}

metrics_df = pd.DataFrame(metrics)
print(metrics_df)
# Out:
#            Humidity and Temperature (C)  \
# MSE Train                      0.601887
# MSE Test                       0.594291
# MAE Train                      0.631286
# MAE Test                       0.625404
#
#            Temperature (C) and Apparent Temperature (C)  \
# MSE Train                                      0.014686
# MSE Test                                       0.014728
# MAE Train                                      0.092798
# MAE Test                                       0.092662
#
#            Apparent Temperature (C) and Humidity
# MSE Train                               0.638247
# MSE Test                                0.624796
# MAE Train                               0.646857
# MAE Test                                0.641951

# %%
# Define input variables
in_vars = ['Temperature (C)', 'Humidity']
input = df_train[['Temperature (C)', 'Humidity']].values
output = df_train['Apparent Temperature (C)'].values
input_test = df_test[['Temperature (C)', 'Humidity']].values
output_test = df_test['Apparent Temperature (C)'].values

# Normalize input and output values
input = scaler.fit_transform(input)
input_test = scaler.transform(input_test)
output = scaler.fit_transform(output.reshape(-1, 1))
output_test = scaler.transform(output_test.reshape(-1, 1))

# Define new input range for plotting
in_range = np.max(input) - np.min(input)
t = np.arange(
    np.min(input) - 0.1 * in_range,
    np.max(input) + 0.1 * in_range,
    0.1
)
t = np.column_stack((t, t))

# Model fitting
rls = RecursiveLeastSquares(n_features=2, forgetting_factor=0.9999)
rls.fit(input, output)
hat = rls.predict(t)

# Create a single figure for all plots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Plotting for each input variable
for i in range(2):
    # Plot Train
    axes[i, 0].scatter(input[:, i], output, c='green', label='Real Data')
    axes[i, 0].plot(t[:, i], hat, c='orange', linewidth=2, label='Prediction')
    axes[i, 0].set_title('Train')
    axes[i, 0].set_ylabel('Apparent Temperature')
    axes[i, 0].set_xlabel(in_vars[i])
    axes[i, 0].legend()

    # Plot Test
    axes[i, 1].scatter(input_test[:, i], output_test, c='blue', label='Real Data')
    axes[i, 1].plot(t[:, i], hat, c='orange', linewidth=2, label='Prediction')
    axes[i, 1].set_title('Test')
    axes[i, 1].set_ylabel('Apparent Temperature')
    axes[i, 1].set_xlabel(in_vars[i])
    axes[i, 1].legend()

# Adjust layout
plt.tight_layout()
plt.show()

# Calculate and print evaluation metrics
mse = mean_squared_error(rls.predict(input), output)
mse_test = mean_squared_error(rls.predict(input_test), output_test)
mae = mean_absolute_error(rls.predict(input), output)
mae_test = mean_absolute_error(rls.predict(input_test), output_test)
metrics = {'MSE Train': mse, 'MSE Test': mse_test, 'MAE Train': mae, 'MAE Test': mae_test}
print(metrics)
# Out:
# {'MSE Train': 0.013632229644933888, 'MSE Test': 0.013781989321699255, 'MAE Train': 0.08834347650871266, 'MAE Test': 0.0884242614058889}

# %% [markdown]
# ##q3-3

# %%
import statsmodels.api as sm

class WeightedLeastSquares:
    def __init__(self):
        self.weights = None
        self.model = None

    def fit(self, X, y):
        # Calculate the weights as 1/var(y)
        self.weights = 1 / np.var(y)

        # Fit the WLS model
        X_with_intercept = sm.add_constant(X)  # Add constant term for intercept
        self.model = sm.WLS(y, X_with_intercept, weights=self.weights)
        self.results = self.model.fit()

    def predict(self, X):
        # Add constant term for intercept
        X_with_intercept = sm.add_constant(X)
        return self.results.predict(X_with_intercept)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df2 = df.sample(frac = 1)
np.random.seed(24)
df_train = df2.sample(frac=0.99)
df_test = df2[~ df.isin(df_train)].dropna()
vars = ['Temperature (C)', 'Apparent Temperature (C)', 'Humidity']
wls_models = dict()
metrices = dict()
for i,v in enumerate(vars):

    # Input of model
    input = df_train[vars[i-1]].values
    output = df_train[v].values
    input_test = df_test[vars[i-1]].values
    output_test = df_test[v].values
    # Nomalizing values
    input = scaler.fit_transform(input.reshape(-1,1))
    input_test = scaler.transform(input_test.reshape(-1,1))
    output  = scaler.fit_transform(output.reshape(-1,1))
    output_test = scaler.transform(output_test.reshape(-1,1))
    # continus variable
    in_range = np.max(input) - np.min(input)
    t = np.arange(
        np.min(input)-0.1*in_range,
        np.max(input)+0.1*in_range,
        0.1 )
    # Model fitting
    wls = WeightedLeastSquares()
    wls.fit(input,output)
    wls_models[v] = wls # Save all LS models
    hat = wls.predict(t.reshape(-1,1))
    # Plot Train
    plt.figure(figsize=(15,6.5))
    plt.subplot(1,2,1)
    plt.scatter(input, output, c='green', label='Real Data')
    plt.plot(t,hat, c='orange',linewidth=2, label='Prediction')
    plt.title('Train')
    plt.ylabel(v)
    plt.xlabel(vars[i-1])
    plt.legend()
    # Plot Test
    plt.subplot(1,2,2)
    plt.scatter(input_test, output_test, c='blue', label='Real Data')
    plt.plot(t,hat, c='orange',linewidth=2, label='Prediction')
    plt.title('Test')
    plt.ylabel(v)
    plt.xlabel(vars[i-1])
    plt.legend()
    # Matrices
    mse = mean_squared_error(wls.predict(input),output)
    mse_test = mean_squared_error(wls.predict(input_test),output_test)
    mae = mean_absolute_error(wls.predict(input),output)
    mae_test = mean_absolute_error(wls.predict(input_test),output_test)
    metrices[v] = {'MSE Train':mse, 'MSE Test':mse_test, 'MAE Train':mae, 'MAE Test':mae_test}
for i, v in enumerate(vars):

    # Input of model
    input_train = df_train[vars[i-1]].values
    output_train = df_train[v].values
    input_test = df_test[vars[i-1]].values
    output_test = df_test[v].values

    # Normalizing values
    input_train_scaled = scaler.fit_transform(input_train.reshape(-1, 1))
    input_test_scaled = scaler.transform(input_test.reshape(-1, 1))
    output_train_scaled = scaler.fit_transform(output_train.reshape(-1, 1))
    output_test_scaled = scaler.transform(output_test.reshape(-1, 1))

    # Model fitting
    # Model fitting
    wls = WeightedLeastSquares()
    wls.fit(input_train_scaled, output_train_scaled)


    # Predictions
    hat_train = wls.predict(input_train_scaled)
    hat_test = wls.predict(input_test_scaled)

    # Matrices
    mse_train = mean_squared_error(output_train_scaled, hat_train)
    mse_test = mean_squared_error(output_test_scaled, hat_test)
    mae_train = mean_absolute_error(output_train_scaled, hat_train)
    mae_test = mean_absolute_error(output_test_scaled, hat_test)
    metrics[f'{vars[i-1]} and {v}'] = {'MSE Train': mse_train, 'MSE Test': mse_test, 'MAE Train': mae_train, 'MAE Test': mae_test}
print(metrics_df)
# Out:
#            Humidity and Temperature (C)  \
# MSE Train                      0.601887
# MSE Test                       0.594291
# MAE Train                      0.631286
# MAE Test                       0.625404
#
#            Temperature (C) and Apparent Temperature (C)  \
# MSE Train                                      0.014686
# MSE Test                                       0.014728
# MAE Train                                      0.092798
# MAE Test                                       0.092662
#
#            Apparent Temperature (C) and Humidity
# MSE Train                               0.638247
# MSE Test                                0.624796
# MAE Train                               0.646857
# MAE Test                                0.641951
